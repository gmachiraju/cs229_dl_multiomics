# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import pandas as pd
import numpy as np
import scipy as sci
from itertools import chain
import pdb
import os
import argparse
import sys

from models import *
from utils import *

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# absolute paths to data and output
# home_dir = "/scratch/users/gmachi/dl_multiomics/cs229_dl_multiomics"

# %%
def str2bool(v):
    if v.lower() in ('yes', 'true', 't', 'y', '1'):
        return True
    elif v.lower() in ('no', 'false', 'f', 'n', '0'):
        return False
    else:
        raise argparse.ArgumentTypeError('Boolean value expected.')


def run_ungrouped_models(X, y, target_names, e_size, args):

    # fit / train the models on single omic -> rna seq
    pca_loadings, pca_transformed = run_pca(X.values, e_size)
    fa_loadings, fa_transformed = run_fa(X.values, e_size)
    ael_loadings, ael_transformed = run_vanilla_autoencoder(X.values, "linear", e_size)
    aer_loadings, aer_transformed = run_vanilla_autoencoder(X.values, "relu", e_size)
    
    # tsne_loadings, tsne_transformed = run_tsne(X.values, e_size) #<--- e_size > 4 is an issue
    # umap_transformed = run_umap(rna.values, e_size)
    # aes_loadings, aes_transformed = run_basic_autoencoder(X.values, "sigmoid", e_size)

    # transpose AE models for consistency
    ael_loadings = ael_loadings.T
    aer_loadings = aer_loadings.T

    method_strings = ["pca", "fa", "ael", "aer"]
    loadings = [pca_loadings, fa_loadings, ael_loadings, aer_loadings]
    transformed = [pca_transformed, fa_transformed, ael_transformed, aer_transformed]

    # write to df and to csv
    print("\nloading dims:\n---------------------------")
    for i, l in enumerate(loadings):
        print(method_strings[i] + ": ", l.shape)
        df = pd.DataFrame.from_records(l)
        outfile = home_dir + "/model_outputs/" + args.dataset + "/loadings_" + args.num_factors + "/" + method_strings[i] + "_loadings.txt"
        df.to_csv(outfile, header=True, index=None, sep=',', mode='a')

    print("\ntransformed dims:\n---------------------------")
    for i, l in enumerate(transformed):
        print(method_strings[i] + ": ", l.shape)
        df = pd.DataFrame.from_records(l)
        outfile = home_dir + "/model_outputs/" + args.dataset + "/transformed_" + args.num_factors + "/" + method_strings[i] + "_transformed.txt"
        df.to_csv(outfile, header=True, index=None, sep=',', mode='a')

    return transformed, method_strings


def run_grouped_models(X, y, target_names, e_size, args):

    # added hyperparam for maui
    h = X.shape[1] # --> can also pick 1100 like Maui creators

    mofa_loadings, mofa_transformed = run_mofa(X, args, e_size)
    maui_loadings, maui_transformed = run_maui(X, args, e_size, h)
    # oivae_encodings = run_oivae(X, args, e_size)

    # get comparable shapes
    maui_loadings = maui_loadings.T
    mofa_transformed = mofa_transformed.T

    method_strings = ["mfa", "maui"]
    loadings = [mofa_loadings, maui_loadings]
    transformed = [mofa_transformed, maui_transformed]

    # write to df and to csv
    print("\nloading dims:\n---------------------------")
    for i, l in enumerate(loadings):
        print(method_strings[i] + ": ", l.shape)
        df = pd.DataFrame.from_records(l)
        outfile = home_dir + "/model_outputs/" + args.dataset + "/loadings_" + args.num_factors + "/" + method_strings[i] + "_loadings.txt"
        df.to_csv(outfile, header=True, index=None, sep=',', mode='a')

    print("\ntransformed dims:\n---------------------------")
    for i, l in enumerate(transformed):
        print(method_strings[i] + ": ", l.shape)
        df = pd.DataFrame.from_records(l)
        outfile = home_dir + "/model_outputs/" + args.dataset + "/transformed_" + args.num_factors + "/" + method_strings[i] + "_transformed.txt"
        df.to_csv(outfile, header=True, index=None, sep=',', mode='a')

    return transformed, method_strings

# %%
def runner(args):

    # read the data
    if args.dataset == "ipop":
        X, y, target_names = load_data(args.dataset)
        Xr, yr, target_names_r = X.loc[:, X.columns.str.startswith('rnaseq')], y, target_names
        
    elif args.dataset == "motrpac":
        Xr, X, yr, y, target_names_r, target_names = load_data(args.dataset)
        
    elif args.dataset == "arabidop1" or args.dataset == "arabidop2":
        X, y, target_names = load_data(args.dataset)
        # not supporting single omics here
        
    elif args.dataset == "tcga":
        X, y, target_names = load_data(args.dataset)
        # not supporting single omics here

    e_size = int(args.num_factors)  # encoding size / number of components (L)

    if args.mode == "run":
        if args.omic == 'single':

            try:
                encs_by_method, method_strings = run_ungrouped_models(Xr, yr, target_names_r, e_size, args.verbosity)
            except:
                print("no single-omics data detected")
                return

            # for i, encs in enumerate(encs_by_method):
                # prediction_task(encs, yr, method_strings[i], args)

        # fit / train the models on multiple (all 5) omics
        elif args.omic == 'multi':

            # Naive approach with stacked data! (ungrouped)
            #-----------------------------------
            encs_by_method_u, method_strings_u = run_ungrouped_models(X, y, target_names, e_size, args)

            # for i, encs in enumerate(encs_by_method_u):
            #     prediction_task(encs, y, method_strings_u[i], args)

            # Grouped analysis!
            #-------------------
            encs_by_method_g, method_strings_g = run_grouped_models(X, y, target_names, e_size, args)
            
            # for i, encs in enumerate(encs_by_method_g):
            #     prediction_task(encs, y, method_strings_g[i], args)

    elif args.mode == "analysis":
        print("run analysis script instead.")
        pass

    elif args.mode == "maui_only":

        args.num_factors = str(70)
        e_size = 70
        h = X.shape[1]

        loadings, transformed = run_maui(X, args, encoding_dim=e_size, hidden_dim=h)  # used to be default h = 1100
        print(loadings.shape)
        print(transformed.shape)

        # write to df and to csv
        print("\nloading dims:\n---------------------------")
        print("maui" + ": ", loadings.shape)
        df = pd.DataFrame.from_records(loadings)
        outfile = home_dir + "/model_outputs/" + args.dataset + "/loadings_" + args.num_factors + "/" + "maui" + "_loadings.txt"
        df.to_csv(outfile, header=True, index=None, sep=',', mode='a')

        print("\ntransformed dims:\n---------------------------")
        print("maui" + ": ", transformed.shape)
        df = pd.DataFrame.from_records(transformed)
        outfile = home_dir + "/model_outputs/" + args.dataset + "/transformed_" + args.num_factors + "/" + "maui" + "_transformed.txt"
        df.to_csv(outfile, header=True, index=None, sep=',', mode='a')

# %% [markdown]
# ## Create Run object

# %%
class RunObj:
  def __init__(self, dataset, num_factors, omic, mode, cached_mfa, cached_vae, verbosity):
    self.dataset = dataset
    self.num_factors = num_factors
    self.omic = omic
    self.mode = mode
    self.cached_mfa = cached_mfa
    self.cached_vae = cached_vae
    self.verbosity = verbosity

# %% [markdown]
# # iPOP dataset

# %%
ipop = RunObj("ipop", "30", "multi", "run", False, False, False)
runner(ipop)
# Out:
# before drop na (589, 11494)
# after drop na (589, 11494)
# before cv filter (589, 11494)
# after cv filter (589, 10835)
# hi, cached mofa
#
#     ###########################################################
#     ###                 __  __  ___  _____ _                ###
#     ###                |  \/  |/ _ \|  ___/ \               ###
#     ###                | |\/| | | | | |_ / _ \              ###
#     ###                | |  | | |_| |  _/ ___ \             ###
#     ###                |_|  |_|\___/|_|/_/   \_\            ###
#     ###                                                     ###
#     ###########################################################
#
#
#
# Loaded view 0 with 589 samples and 9883 features...
# Loaded view 1 with 589 samples and 237 features...
# Loaded view 2 with 589 samples and 643 features...
# Loaded view 3 with 589 samples and 48 features...
# Loaded view 4 with 589 samples and 24 features...
#
# ##############################################
# ## Doing sanity checks and parsing the data ##
# ##############################################
#
# Warning: you are scaling the Gaussian views to unit variance. As long as the scale of the different views is not massively different, the model does not require this
# Centering features for view rnaseq...
# Scaling view rnaseq to unit variance...
# Centering features for view prot...
# Scaling view prot to unit variance...
# Centering features for view metab...
# Scaling view metab to unit variance...
# Centering features for view cytok...
# Scaling view cytok to unit variance...
# Centering features for view clinic...
# Scaling view clinic to unit variance...
#
# After parsing the data:
# view rnaseq has 589 samples and 9883 features...
# view prot has 589 samples and 237 features...
# view metab has 589 samples and 643 features...
# view cytok has 589 samples and 48 features...
# view clinic has 589 samples and 24 features...
#
# Likelihoods are defined as:
# 	rnaseq: gaussian
# 	prot: gaussian
# 	metab: gaussian
# 	cytok: gaussian
# 	clinic: gaussian
#
#
# ########################
# ## Building the model ##
# ########################
#
#
# Setting random seed 2019...
#
#
# ##################################
# ## Running MOFA with seed 2019 ##
# ##################################
#
#
# Iteration 1: time=5.22, Factors=30
# Iteration 2: time=5.20, Factors=30
# Iteration 3: time=5.31, Factors=30
# Iteration 4: time=5.23, Factors=30
# Iteration 5: time=5.29, Factors=30
# Iteration 6: time=5.27, Factors=30
# Iteration 8: time=5.30 ELBO=-7765767.59, deltaELBO=17542.0473, Factors=30
# Iteration 9: time=5.29 ELBO=-7751324.61, deltaELBO=14442.9813, Factors=30
# Iteration 10: time=5.26 ELBO=-7739041.88, deltaELBO=12282.7331, Factors=30
#
#
# ###########################################
# ## Training finished, processing results ##
# ###########################################
#
#
# Saving model in /scratch/users/gmachi/dl_multiomics/cs229_dl_multiomics/ipop.hdf5...
#
# Sample names not provided...
# Feature names not provided...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-01fd86e59a38> in <module>
#       1 ipop = RunObj("ipop", 30, "multi", "run", False, False, False)
# ----> 2 runner(ipop)
#
# <ipython-input-17-8db96026d109> in runner(args)
#      43             # Grouped analysis!
#      44             #-------------------
# ---> 45             encs_by_method_g, method_strings_g = run_grouped_models(X, y, target_names, e_size, args)
#      46
#      47             # for i, encs in enumerate(encs_by_method_g):
#
# <ipython-input-16-2e5f9a74b966> in run_grouped_models(X, y, target_names, e_size, args)
#      52
#      53     mofa_loadings, mofa_transformed = run_mofa(X, args, e_size)
# ---> 54     maui_loadings, maui_transformed = run_maui(X, args, e_size, h)
#      55     # oivae_encodings = run_oivae(X, args, e_size)
#      56
#
# /scratch/users/gmachi/dl_multiomics/cs229_dl_multiomics/models.py in run_maui(X, args, encoding_dim, hidden_dim, epochs)
#     363         if args.dataset == "ipop":
#     364             X_embedded = maui_model.fit_transform(
# --> 365                 {'rnaseq': rnaseq, 'prot': prot, 'metab': metab, 'cytok': cytok, 'clinic': clinic})  # aka. z
#     366         elif args.dataset == "arabidop1":
#     367             X_embedded = maui_model.fit_transform(
#
# ~/.local/lib/python3.6/site-packages/maui/model.py in fit_transform(self, X, y, X_validation, encoder)
#     134             Latent factors representation of the data X.
#     135         """
# --> 136         self.fit(X, X_validation=X_validation, y=y)
#     137         return self.transform(X, encoder=encoder)
#     138
#
# ~/.local/lib/python3.6/site-packages/maui/model.py in fit(self, X, y, X_validation)
#      72             self.x_, x_test,
#      73             hidden_dims=self.n_hidden, latent_dim=self.n_latent,
# ---> 74             batch_size=self.batch_size, epochs=self.epochs)
#      75         self.hist = pd.DataFrame(hist.history)
#      76         self.vae = vae
#
# ~/.local/lib/python3.6/site-packages/maui/autoencoders_architectures.py in stacked_vae(x_train, x_val, hidden_dims, latent_dim, initial_beta_val, learning_rate, epsilon_std, kappa, epochs, batch_size, batch_normalize_inputs, batch_normalize_intermediaries, batch_normalize_embedding, relu_intermediaries, relu_embedding, max_beta_val)
#     196                    batch_size=batch_size,
#     197                    validation_data=(np.array(x_val), None),
# --> 198                    callbacks=[LadderCallback(beta, kappa, max_beta_val)])
#     199
#     200     # non-sampling encoder
#
# ~/.local/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# ~/.local/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# ~/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %% [markdown]
# # TCGA dataset

# %%
tcga = RunObj("tcga", "70", "multi", "run", True, True, False)
runner(tcga)
# Out:
# loading dims:
# ---------------------------
# pca:  (70, 1300)
# fa:  (70, 1300)
# ael:  (70, 1300)
# aer:  (70, 1300)
#
# transformed dims:
# ---------------------------
# pca:  (573, 70)
# fa:  (573, 70)
# ael:  (573, 70)
# aer:  (573, 70)
# hi, cached mofa
#
#     ###########################################################
#     ###                 __  __  ___  _____ _                ###
#     ###                |  \/  |/ _ \|  ___/ \               ###
#     ###                | |\/| | | | | |_ / _ \              ###
#     ###                | |  | | |_| |  _/ ___ \             ###
#     ###                |_|  |_|\___/|_|/_/   \_\            ###
#     ###                                                     ###
#     ###########################################################
#
#
#
# Loaded view 0 with 573 samples and 1000 features...
# Loaded view 1 with 573 samples and 200 features...
# Loaded view 2 with 573 samples and 100 features...
#
# ##############################################
# ## Doing sanity checks and parsing the data ##
# ##############################################
#
# Warning: you are scaling the Gaussian views to unit variance. As long as the scale of the different views is not massively different, the model does not require this
# Centering features for view gex...
# Scaling view gex to unit variance...
# Centering features for view mut...
# Scaling view mut to unit variance...
# Centering features for view cnv...
# Scaling view cnv to unit variance...
#
# After parsing the data:
# view gex has 573 samples and 1000 features...
# view mut has 573 samples and 200 features...
# view cnv has 573 samples and 100 features...
#
# Likelihoods are defined as:
# 	gex: gaussian
# 	mut: gaussian
# 	cnv: gaussian
#
#
# ########################
# ## Building the model ##
# ########################
#
#
# Setting random seed 2019...
#
#
# ##################################
# ## Running MOFA with seed 2019 ##
# ##################################
#
#
# Iteration 1: time=1.21, Factors=70
# Iteration 2: time=1.22, Factors=70
# Iteration 3: time=1.22, Factors=70
# Iteration 4: time=1.21, Factors=70
# Iteration 5: time=1.21, Factors=70
# Iteration 971: time=1.23 ELBO=-693908.15, deltaELBO=2.3821, Factors=70
# Iteration 972: time=1.22 ELBO=-693905.72, deltaELBO=2.4392, Factors=70
# Iteration 973: time=1.22 ELBO=-693902.98, deltaELBO=2.7393, Factors=70
# Iteration 974: time=1.22 ELBO=-693896.31, deltaELBO=6.6639, Factors=70
# Iteration 975: time=1.25 ELBO=-693883.72, deltaELBO=12.5902, Factors=70
# Iteration 976: time=1.31 ELBO=-693880.47, deltaELBO=3.2507, Factors=70
# Iteration 977: time=1.24 ELBO=-693877.89, deltaELBO=2.5853, Factors=70
# Iteration 978: time=1.23 ELBO=-693875.47, deltaELBO=2.4189, Factors=70
# Iteration 979: time=1.23 ELBO=-693873.08, deltaELBO=2.3875, Factors=70
# Iteration 980: time=1.24 ELBO=-693870.69, deltaELBO=2.3868, Factors=70
# Iteration 981: time=1.28 ELBO=-693868.30, deltaELBO=2.3977, Factors=70
# Iteration 982: time=1.24 ELBO=-693865.87, deltaELBO=2.4219, Factors=70
# Iteration 983: time=1.22 ELBO=-693863.41, deltaELBO=2.4660, Factors=70
# Iteration 984: time=1.31 ELBO=-693860.89, deltaELBO=2.5194, Factors=70
# Iteration 985: time=1.25 ELBO=-693858.37, deltaELBO=2.5144, Factors=70
# Iteration 986: time=1.23 ELBO=-693855.94, deltaELBO=2.4310, Factors=70
# Iteration 987: time=1.24 ELBO=-693853.58, deltaELBO=2.3671, Factors=70
# Iteration 988: time=1.25 ELBO=-693851.23, deltaELBO=2.3433, Factors=70
# Iteration 989: time=1.25 ELBO=-693848.90, deltaELBO=2.3370, Factors=70
# Iteration 990: time=1.22 ELBO=-693846.56, deltaELBO=2.3364, Factors=70
# Iteration 991: time=1.25 ELBO=-693844.22, deltaELBO=2.3371, Factors=70
# Iteration 992: time=1.25 ELBO=-693841.88, deltaELBO=2.3378, Factors=70
# Iteration 993: time=1.32 ELBO=-693839.55, deltaELBO=2.3384, Factors=70
# Iteration 994: time=1.25 ELBO=-693837.21, deltaELBO=2.3395, Factors=70
# Iteration 995: time=1.22 ELBO=-693834.87, deltaELBO=2.3412, Factors=70
# Iteration 996: time=1.23 ELBO=-693832.52, deltaELBO=2.3445, Factors=70
# Iteration 997: time=1.24 ELBO=-693830.17, deltaELBO=2.3504, Factors=70
# Iteration 998: time=1.23 ELBO=-693827.81, deltaELBO=2.3601, Factors=70
# Iteration 999: time=1.25 ELBO=-693825.44, deltaELBO=2.3709, Factors=70
# Iteration 1000: time=1.23 ELBO=-693823.07, deltaELBO=2.3716, Factors=70
#
#
# ###########################################
# ## Training finished, processing results ##
# ###########################################
#
#
# Saving model in /scratch/users/gmachi/dl_multiomics/cs229_dl_multiomics/tcga.hdf5...
#
# Sample names not provided...
# Feature names not provided...
#
# loading dims:
# ---------------------------
# mfa:  (70, 1300)
# maui:  (70, 1300)
#
# transformed dims:
# ---------------------------
# mfa:  (573, 70)
# maui:  (573, 70)

# %% [markdown]
# # Pioneer Dataset

# %%
pioneer = RunObj("pioneer", 20, "multi", "run", False, False, False)
runner(pioneer)
